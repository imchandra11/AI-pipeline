# %%
print("hello")
# Out:
# hello

# %%
from Classification.modelmodule import ModelModuleCLS
from Classification.datamodule import DataModuleCLS

# %run Classification/mainfittest.py --config StressLevelPrediction/configs/stress.yaml

# %run Classification/mainfittest.py --config StressLevelPrediction/configs/stress.yaml --config StressLevelPrediction/configs/stress.local.yaml
# Out:
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\fabric\utilities\seed.py:44: No seed found, seed set to 0
# Seed set to 0
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\cli.py:734: `ModelModuleCLS.configure_optimizers` will be overridden by `CLSLightningCLI.configure_optimizers`.
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:479: You passed `Trainer(accelerator='cpu', precision='16-mixed')` but AMP with fp16 is not supported on CPU. Using `precision='bf16-mixed'` instead.
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\utilities\model_summary\model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#    | Name            | Type                | Params | Mode  | FLOPs
# -------------------------------------------------------------------------
# 0  | model           | ClassificationModel | 13.0 K | train | 0
# 1  | criterion       | CrossEntropyLoss    | 0      | train | 0
# 2  | train_accuracy  | MulticlassAccuracy  | 0      | train | 0
# 3  | val_accuracy    | MulticlassAccuracy  | 0      | train | 0
# 4  | test_accuracy   | MulticlassAccuracy  | 0      | train | 0
# 5  | train_f1        | MulticlassF1Score   | 0      | train | 0
# 6  | val_f1          | MulticlassF1Score   | 0      | train | 0
# 7  | test_f1         | MulticlassF1Score   | 0      | train | 0
# 8  | train_precision | MulticlassPrecision | 0      | train | 0
# 9  | val_precision   | MulticlassPrecision | 0      | train | 0
# 10 | test_precision  | MulticlassPrecision | 0      | train | 0
# 11 | train_recall    | MulticlassRecall    | 0      | train | 0
# 12 | val_recall      | MulticlassRecall    | 0      | train | 0
# 13 | test_recall     | MulticlassRecall    | 0      | train | 0
# -------------------------------------------------------------------------
# 13.0 K    Trainable params
# 0         Non-trainable params
# 13.0 K    Total params
# 0.052     Total estimated model params size (MB)
# 26        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 10/10 [00:00<00:00, 18.15it/s, v_num=0, train_loss_step=1.650, val_loss=1.610, val_acc=0.202]
# Epoch 0, global step 10: 'val_loss' reached 1.61389 (best 1.61389), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=0-val_loss=1.61.best.ckpt' as top 1
# Epoch 0, global step 10: 'step' reached 10.00000 (best 10.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=0.last.ckpt' as top 1
# Epoch 1: 100%|██████████| 10/10 [00:00<00:00, 17.11it/s, v_num=0, train_loss_step=1.650, val_loss=1.620, val_acc=0.191, train_loss_epoch=1.680, train_acc=0.192]
# Epoch 1, global step 20: 'val_loss' was not in top 1
# Epoch 1, global step 20: 'step' reached 20.00000 (best 20.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=1.last.ckpt' as top 1
# Epoch 2: 100%|██████████| 10/10 [00:00<00:00, 19.91it/s, v_num=0, train_loss_step=1.690, val_loss=1.630, val_acc=0.214, train_loss_epoch=1.680, train_acc=0.205]
# Epoch 2, global step 30: 'val_loss' was not in top 1
# Epoch 2, global step 30: 'step' reached 30.00000 (best 30.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=2.last.ckpt' as top 1
# Epoch 3: 100%|██████████| 10/10 [00:00<00:00, 18.01it/s, v_num=0, train_loss_step=1.640, val_loss=1.630, val_acc=0.214, train_loss_epoch=1.680, train_acc=0.212]
# Epoch 3, global step 40: 'val_loss' was not in top 1
# Epoch 3, global step 40: 'step' reached 40.00000 (best 40.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=3.last.ckpt' as top 1
# Epoch 4: 100%|██████████| 10/10 [00:00<00:00, 12.00it/s, v_num=0, train_loss_step=1.590, val_loss=1.640, val_acc=0.211, train_loss_epoch=1.670, train_acc=0.204]
# Epoch 4, global step 50: 'val_loss' was not in top 1
# Epoch 4, global step 50: 'step' reached 50.00000 (best 50.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=4.last.ckpt' as top 1
# Epoch 5: 100%|██████████| 10/10 [00:01<00:00,  8.79it/s, v_num=0, train_loss_step=1.610, val_loss=1.640, val_acc=0.203, train_loss_epoch=1.660, train_acc=0.212]
# Epoch 5, global step 60: 'val_loss' was not in top 1
# Epoch 5, global step 60: 'step' reached 60.00000 (best 60.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=5.last.ckpt' as top 1
# Epoch 6: 100%|██████████| 10/10 [00:00<00:00, 15.06it/s, v_num=0, train_loss_step=1.660, val_loss=1.640, val_acc=0.198, train_loss_epoch=1.660, train_acc=0.204]
# Epoch 6, global step 70: 'val_loss' was not in top 1
# Epoch 6, global step 70: 'step' reached 70.00000 (best 70.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=6.last.ckpt' as top 1
# Epoch 7: 100%|██████████| 10/10 [00:00<00:00, 17.77it/s, v_num=0, train_loss_step=1.720, val_loss=1.640, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.203]
# Epoch 7, global step 80: 'val_loss' was not in top 1
# Epoch 7, global step 80: 'step' reached 80.00000 (best 80.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=7.last.ckpt' as top 1
# Epoch 8: 100%|██████████| 10/10 [00:00<00:00, 15.95it/s, v_num=0, train_loss_step=1.710, val_loss=1.640, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.207]
# Epoch 8, global step 90: 'val_loss' was not in top 1
# Epoch 8, global step 90: 'step' reached 90.00000 (best 90.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=8.last.ckpt' as top 1
# Epoch 9: 100%|██████████| 10/10 [00:00<00:00, 22.26it/s, v_num=0, train_loss_step=1.660, val_loss=1.630, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.208]
# Epoch 9, global step 100: 'val_loss' was not in top 1
# Epoch 9, global step 100: 'step' reached 100.00000 (best 100.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=9.last.ckpt' as top 1
# Epoch 10: 100%|██████████| 10/10 [00:00<00:00, 14.86it/s, v_num=0, train_loss_step=1.620, val_loss=1.630, val_acc=0.198, train_loss_epoch=1.650, train_acc=0.202]
# Epoch 10, global step 110: 'val_loss' was not in top 1
# Epoch 10, global step 110: 'step' reached 110.00000 (best 110.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=10.last.ckpt' as top 1
# Epoch 11: 100%|██████████| 10/10 [00:00<00:00, 15.72it/s, v_num=0, train_loss_step=1.630, val_loss=1.630, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.214]
# Epoch 11, global step 120: 'val_loss' was not in top 1
# Epoch 11, global step 120: 'step' reached 120.00000 (best 120.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=11.last.ckpt' as top 1
# Epoch 12: 100%|██████████| 10/10 [00:00<00:00, 19.26it/s, v_num=0, train_loss_step=1.620, val_loss=1.630, val_acc=0.204, train_loss_epoch=1.650, train_acc=0.207]
# Epoch 12, global step 130: 'val_loss' was not in top 1
# Epoch 12, global step 130: 'step' reached 130.00000 (best 130.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=12.last.ckpt' as top 1
# Epoch 13: 100%|██████████| 10/10 [00:00<00:00, 17.82it/s, v_num=0, train_loss_step=1.610, val_loss=1.630, val_acc=0.197, train_loss_epoch=1.640, train_acc=0.212]
# Epoch 13, global step 140: 'val_loss' was not in top 1
# Epoch 13, global step 140: 'step' reached 140.00000 (best 140.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=13.last.ckpt' as top 1
# Epoch 14: 100%|██████████| 10/10 [00:00<00:00, 22.91it/s, v_num=0, train_loss_step=1.610, val_loss=1.630, val_acc=0.195, train_loss_epoch=1.630, train_acc=0.230]
# Epoch 14, global step 150: 'val_loss' was not in top 1
# Epoch 14, global step 150: 'step' reached 150.00000 (best 150.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=14.last.ckpt' as top 1
# Epoch 15: 100%|██████████| 10/10 [00:00<00:00, 24.20it/s, v_num=0, train_loss_step=1.580, val_loss=1.630, val_acc=0.195, train_loss_epoch=1.640, train_acc=0.212]
# Epoch 15, global step 160: 'val_loss' was not in top 1
# Epoch 15, global step 160: 'step' reached 160.00000 (best 160.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=15.last.ckpt' as top 1
# Epoch 16: 100%|██████████| 10/10 [00:00<00:00, 10.68it/s, v_num=0, train_loss_step=1.640, val_loss=1.630, val_acc=0.205, train_loss_epoch=1.630, train_acc=0.212]
# Epoch 16, global step 170: 'val_loss' was not in top 1
# Epoch 16, global step 170: 'step' reached 170.00000 (best 170.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=16.last.ckpt' as top 1
# Epoch 17: 100%|██████████| 10/10 [00:00<00:00, 19.28it/s, v_num=0, train_loss_step=1.620, val_loss=1.630, val_acc=0.204, train_loss_epoch=1.620, train_acc=0.216]
# Epoch 17, global step 180: 'val_loss' was not in top 1
# Epoch 17, global step 180: 'step' reached 180.00000 (best 180.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=17.last.ckpt' as top 1
# Epoch 18: 100%|██████████| 10/10 [00:00<00:00, 21.29it/s, v_num=0, train_loss_step=1.660, val_loss=1.630, val_acc=0.201, train_loss_epoch=1.630, train_acc=0.217]
# Epoch 18, global step 190: 'val_loss' was not in top 1
# Epoch 18, global step 190: 'step' reached 190.00000 (best 190.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=18.last.ckpt' as top 1
# Epoch 19: 100%|██████████| 10/10 [00:00<00:00, 20.52it/s, v_num=0, train_loss_step=1.650, val_loss=1.630, val_acc=0.197, train_loss_epoch=1.620, train_acc=0.233]
# Epoch 19, global step 200: 'val_loss' was not in top 1
# Epoch 19, global step 200: 'step' reached 200.00000 (best 200.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=19.last.ckpt' as top 1
# Epoch 20: 100%|██████████| 10/10 [00:00<00:00, 19.75it/s, v_num=0, train_loss_step=1.600, val_loss=1.630, val_acc=0.202, train_loss_epoch=1.630, train_acc=0.216]
# Epoch 20, global step 210: 'val_loss' was not in top 1
# Epoch 20, global step 210: 'step' reached 210.00000 (best 210.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=20.last.ckpt' as top 1
# Epoch 21: 100%|██████████| 10/10 [00:00<00:00, 12.88it/s, v_num=0, train_loss_step=1.670, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.610, train_acc=0.243]
# Epoch 21, global step 220: 'val_loss' was not in top 1
# Epoch 21, global step 220: 'step' reached 220.00000 (best 220.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=21.last.ckpt' as top 1
# Epoch 22: 100%|██████████| 10/10 [00:00<00:00, 21.55it/s, v_num=0, train_loss_step=1.640, val_loss=1.630, val_acc=0.204, train_loss_epoch=1.620, train_acc=0.221]
# Epoch 22, global step 230: 'val_loss' was not in top 1
# Epoch 22, global step 230: 'step' reached 230.00000 (best 230.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=22.last.ckpt' as top 1
# Epoch 23: 100%|██████████| 10/10 [00:00<00:00, 18.18it/s, v_num=0, train_loss_step=1.560, val_loss=1.630, val_acc=0.202, train_loss_epoch=1.610, train_acc=0.227]
# Epoch 23, global step 240: 'val_loss' was not in top 1
# Epoch 23, global step 240: 'step' reached 240.00000 (best 240.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=23.last.ckpt' as top 1
# Epoch 24: 100%|██████████| 10/10 [00:00<00:00, 19.46it/s, v_num=0, train_loss_step=1.620, val_loss=1.630, val_acc=0.210, train_loss_epoch=1.610, train_acc=0.230]
# Epoch 24, global step 250: 'val_loss' was not in top 1
# Epoch 24, global step 250: 'step' reached 250.00000 (best 250.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=24.last.ckpt' as top 1
# Epoch 25: 100%|██████████| 10/10 [00:00<00:00, 17.67it/s, v_num=0, train_loss_step=1.570, val_loss=1.630, val_acc=0.205, train_loss_epoch=1.610, train_acc=0.241]
# Epoch 25, global step 260: 'val_loss' was not in top 1
# Epoch 25, global step 260: 'step' reached 260.00000 (best 260.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=25.last.ckpt' as top 1
# Epoch 26: 100%|██████████| 10/10 [00:00<00:00, 12.53it/s, v_num=0, train_loss_step=1.580, val_loss=1.630, val_acc=0.203, train_loss_epoch=1.610, train_acc=0.233]
# Epoch 26, global step 270: 'val_loss' was not in top 1
# Epoch 26, global step 270: 'step' reached 270.00000 (best 270.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=26.last.ckpt' as top 1
# Epoch 27: 100%|██████████| 10/10 [00:00<00:00, 16.67it/s, v_num=0, train_loss_step=1.600, val_loss=1.630, val_acc=0.202, train_loss_epoch=1.600, train_acc=0.240]
# Epoch 27, global step 280: 'val_loss' was not in top 1
# Epoch 27, global step 280: 'step' reached 280.00000 (best 280.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=27.last.ckpt' as top 1
# Epoch 28: 100%|██████████| 10/10 [00:00<00:00, 18.73it/s, v_num=0, train_loss_step=1.590, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.600, train_acc=0.241]
# Epoch 28, global step 290: 'val_loss' was not in top 1
# Epoch 28, global step 290: 'step' reached 290.00000 (best 290.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=28.last.ckpt' as top 1
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 21.70it/s, v_num=0, train_loss_step=1.600, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.590, train_acc=0.258]
# Epoch 29, global step 300: 'val_loss' was not in top 1
# Epoch 29, global step 300: 'step' reached 300.00000 (best 300.00000), saving model to 'StressLevelPrediction/lightning_logs\\StressLevelTraining\\version_0\\checkpoints\\epoch=29.last.ckpt' as top 1
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 20.37it/s, v_num=0, train_loss_step=1.600, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.610, train_acc=0.236]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# ✓ Model exported to ONNX: StressLevelPrediction\models\stress_level_model.onnx
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 13.80it/s, v_num=0, train_loss_step=1.600, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.610, train_acc=0.236]
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:160: `.test(ckpt_path="best")` is called with Trainer configured with multiple `ModelCheckpoint` callbacks. It will use the best checkpoint path from first checkpoint callback.
# Restoring states from the checkpoint path at StressLevelPrediction/lightning_logs\StressLevelTraining\version_0\checkpoints\epoch=0-val_loss=1.61.best.ckpt
# Loaded model weights from the checkpoint at StressLevelPrediction/lightning_logs\StressLevelTraining\version_0\checkpoints\epoch=0-val_loss=1.61.best.ckpt
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 10.97it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.20191580057144165
#          test_f1            0.0857270285487175
#         test_loss           1.6138904094696045
#      test_precision         0.1093897819519043
#        test_recall          0.20191580057144165
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
