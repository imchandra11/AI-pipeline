# %%
print("hello")
# Out:
# hello

# %%
from Classification.modelmodule import ModelModuleCLS
from Classification.datamodule import DataModuleCLS

# %run Classification/mainfittest.py --config StressLevelPrediction/configs/stress.yaml

# %run Classification/mainfittest.py --config StressLevelPrediction/configs/stress.yaml --config StressLevelPrediction/configs/stress.local.yaml
# Out:
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\fabric\utilities\seed.py:44: No seed found, seed set to 0
# Seed set to 0
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\cli.py:734: `ModelModuleCLS.configure_optimizers` will be overridden by `CLSLightningCLI.configure_optimizers`.
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:479: You passed `Trainer(accelerator='cpu', precision='16-mixed')` but AMP with fp16 is not supported on CPU. Using `precision='bf16-mixed'` instead.
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\utilities\model_summary\model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#    | Name            | Type                | Params | Mode  | FLOPs
# -------------------------------------------------------------------------
# 0  | model           | ClassificationModel | 13.0 K | train | 0
# 1  | criterion       | CrossEntropyLoss    | 0      | train | 0
# 2  | train_accuracy  | MulticlassAccuracy  | 0      | train | 0
# 3  | val_accuracy    | MulticlassAccuracy  | 0      | train | 0
# 4  | test_accuracy   | MulticlassAccuracy  | 0      | train | 0
# 5  | train_f1        | MulticlassF1Score   | 0      | train | 0
# 6  | val_f1          | MulticlassF1Score   | 0      | train | 0
# 7  | test_f1         | MulticlassF1Score   | 0      | train | 0
# 8  | train_precision | MulticlassPrecision | 0      | train | 0
# 9  | val_precision   | MulticlassPrecision | 0      | train | 0
# 10 | test_precision  | MulticlassPrecision | 0      | train | 0
# 11 | train_recall    | MulticlassRecall    | 0      | train | 0
# 12 | val_recall      | MulticlassRecall    | 0      | train | 0
# 13 | test_recall     | MulticlassRecall    | 0      | train | 0
# -------------------------------------------------------------------------
# 13.0 K    Trainable params
# 0         Non-trainable params
# 13.0 K    Total params
# 0.052     Total estimated model params size (MB)
# 26        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 10/10 [00:00<00:00, 20.66it/s, v_num=1, train_loss_step=1.650, val_loss=1.610, val_acc=0.202]
# Epoch 0, global step 10: 'val_loss' reached 1.61389 (best 1.61389), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=0-val_loss=1.61.best.ckpt' as top 1
# Epoch 0, global step 10: 'step' reached 10.00000 (best 10.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=0.last.ckpt' as top 1
# Epoch 1: 100%|██████████| 10/10 [00:00<00:00, 22.64it/s, v_num=1, train_loss_step=1.650, val_loss=1.620, val_acc=0.191, train_loss_epoch=1.680, train_acc=0.192]
# Epoch 1, global step 20: 'val_loss' was not in top 1
# Epoch 1, global step 20: 'step' reached 20.00000 (best 20.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=1.last.ckpt' as top 1
# Epoch 2: 100%|██████████| 10/10 [00:00<00:00, 23.25it/s, v_num=1, train_loss_step=1.690, val_loss=1.630, val_acc=0.214, train_loss_epoch=1.680, train_acc=0.205]
# Epoch 2, global step 30: 'val_loss' was not in top 1
# Epoch 2, global step 30: 'step' reached 30.00000 (best 30.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=2.last.ckpt' as top 1
# Epoch 3: 100%|██████████| 10/10 [00:00<00:00, 13.06it/s, v_num=1, train_loss_step=1.640, val_loss=1.630, val_acc=0.214, train_loss_epoch=1.680, train_acc=0.212]
# Epoch 3, global step 40: 'val_loss' was not in top 1
# Epoch 3, global step 40: 'step' reached 40.00000 (best 40.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=3.last.ckpt' as top 1
# Epoch 4: 100%|██████████| 10/10 [00:00<00:00, 18.69it/s, v_num=1, train_loss_step=1.590, val_loss=1.640, val_acc=0.211, train_loss_epoch=1.670, train_acc=0.204]
# Epoch 4, global step 50: 'val_loss' was not in top 1
# Epoch 4, global step 50: 'step' reached 50.00000 (best 50.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=4.last.ckpt' as top 1
# Epoch 5: 100%|██████████| 10/10 [00:00<00:00, 19.42it/s, v_num=1, train_loss_step=1.610, val_loss=1.640, val_acc=0.203, train_loss_epoch=1.660, train_acc=0.212]
# Epoch 5, global step 60: 'val_loss' was not in top 1
# Epoch 5, global step 60: 'step' reached 60.00000 (best 60.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=5.last.ckpt' as top 1
# Epoch 6: 100%|██████████| 10/10 [00:00<00:00, 21.94it/s, v_num=1, train_loss_step=1.660, val_loss=1.640, val_acc=0.198, train_loss_epoch=1.660, train_acc=0.204]
# Epoch 6, global step 70: 'val_loss' was not in top 1
# Epoch 6, global step 70: 'step' reached 70.00000 (best 70.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=6.last.ckpt' as top 1
# Epoch 7: 100%|██████████| 10/10 [00:00<00:00, 18.76it/s, v_num=1, train_loss_step=1.720, val_loss=1.640, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.203]
# Epoch 7, global step 80: 'val_loss' was not in top 1
# Epoch 7, global step 80: 'step' reached 80.00000 (best 80.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=7.last.ckpt' as top 1
# Epoch 8: 100%|██████████| 10/10 [00:00<00:00, 17.34it/s, v_num=1, train_loss_step=1.710, val_loss=1.640, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.207]
# Epoch 8, global step 90: 'val_loss' was not in top 1
# Epoch 8, global step 90: 'step' reached 90.00000 (best 90.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=8.last.ckpt' as top 1
# Epoch 9: 100%|██████████| 10/10 [00:00<00:00, 21.59it/s, v_num=1, train_loss_step=1.660, val_loss=1.630, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.208]
# Epoch 9, global step 100: 'val_loss' was not in top 1
# Epoch 9, global step 100: 'step' reached 100.00000 (best 100.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=9.last.ckpt' as top 1
# Epoch 10: 100%|██████████| 10/10 [00:00<00:00, 11.79it/s, v_num=1, train_loss_step=1.620, val_loss=1.630, val_acc=0.198, train_loss_epoch=1.650, train_acc=0.202]
# Epoch 10, global step 110: 'val_loss' was not in top 1
# Epoch 10, global step 110: 'step' reached 110.00000 (best 110.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=10.last.ckpt' as top 1
# Epoch 11: 100%|██████████| 10/10 [00:00<00:00, 19.42it/s, v_num=1, train_loss_step=1.630, val_loss=1.630, val_acc=0.201, train_loss_epoch=1.660, train_acc=0.214]
# Epoch 11, global step 120: 'val_loss' was not in top 1
# Epoch 11, global step 120: 'step' reached 120.00000 (best 120.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=11.last.ckpt' as top 1
# Epoch 12: 100%|██████████| 10/10 [00:00<00:00, 13.92it/s, v_num=1, train_loss_step=1.620, val_loss=1.630, val_acc=0.204, train_loss_epoch=1.650, train_acc=0.207]
# Epoch 12, global step 130: 'val_loss' was not in top 1
# Epoch 12, global step 130: 'step' reached 130.00000 (best 130.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=12.last.ckpt' as top 1
# Epoch 13: 100%|██████████| 10/10 [00:00<00:00, 14.50it/s, v_num=1, train_loss_step=1.610, val_loss=1.630, val_acc=0.197, train_loss_epoch=1.640, train_acc=0.212]
# Epoch 13, global step 140: 'val_loss' was not in top 1
# Epoch 13, global step 140: 'step' reached 140.00000 (best 140.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=13.last.ckpt' as top 1
# Epoch 14: 100%|██████████| 10/10 [00:00<00:00, 14.74it/s, v_num=1, train_loss_step=1.610, val_loss=1.630, val_acc=0.195, train_loss_epoch=1.630, train_acc=0.230]
# Epoch 14, global step 150: 'val_loss' was not in top 1
# Epoch 14, global step 150: 'step' reached 150.00000 (best 150.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=14.last.ckpt' as top 1
# Epoch 15: 100%|██████████| 10/10 [00:00<00:00, 20.36it/s, v_num=1, train_loss_step=1.580, val_loss=1.630, val_acc=0.195, train_loss_epoch=1.640, train_acc=0.212]
# Epoch 15, global step 160: 'val_loss' was not in top 1
# Epoch 15, global step 160: 'step' reached 160.00000 (best 160.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=15.last.ckpt' as top 1
# Epoch 16: 100%|██████████| 10/10 [00:00<00:00, 15.67it/s, v_num=1, train_loss_step=1.640, val_loss=1.630, val_acc=0.205, train_loss_epoch=1.630, train_acc=0.212]
# Epoch 16, global step 170: 'val_loss' was not in top 1
# Epoch 16, global step 170: 'step' reached 170.00000 (best 170.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=16.last.ckpt' as top 1
# Epoch 17: 100%|██████████| 10/10 [00:00<00:00, 16.68it/s, v_num=1, train_loss_step=1.620, val_loss=1.630, val_acc=0.204, train_loss_epoch=1.620, train_acc=0.216]
# Epoch 17, global step 180: 'val_loss' was not in top 1
# Epoch 17, global step 180: 'step' reached 180.00000 (best 180.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=17.last.ckpt' as top 1
# Epoch 18: 100%|██████████| 10/10 [00:00<00:00, 12.20it/s, v_num=1, train_loss_step=1.660, val_loss=1.630, val_acc=0.201, train_loss_epoch=1.630, train_acc=0.217]
# Epoch 18, global step 190: 'val_loss' was not in top 1
# Epoch 18, global step 190: 'step' reached 190.00000 (best 190.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=18.last.ckpt' as top 1
# Epoch 19: 100%|██████████| 10/10 [00:00<00:00, 20.14it/s, v_num=1, train_loss_step=1.650, val_loss=1.630, val_acc=0.197, train_loss_epoch=1.620, train_acc=0.233]
# Epoch 19, global step 200: 'val_loss' was not in top 1
# Epoch 19, global step 200: 'step' reached 200.00000 (best 200.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=19.last.ckpt' as top 1
# Epoch 20: 100%|██████████| 10/10 [00:00<00:00, 17.73it/s, v_num=1, train_loss_step=1.600, val_loss=1.630, val_acc=0.202, train_loss_epoch=1.630, train_acc=0.216]
# Epoch 20, global step 210: 'val_loss' was not in top 1
# Epoch 20, global step 210: 'step' reached 210.00000 (best 210.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=20.last.ckpt' as top 1
# Epoch 21: 100%|██████████| 10/10 [00:00<00:00, 10.52it/s, v_num=1, train_loss_step=1.670, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.610, train_acc=0.243]
# Epoch 21, global step 220: 'val_loss' was not in top 1
# Epoch 21, global step 220: 'step' reached 220.00000 (best 220.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=21.last.ckpt' as top 1
# Epoch 22: 100%|██████████| 10/10 [00:00<00:00, 23.19it/s, v_num=1, train_loss_step=1.640, val_loss=1.630, val_acc=0.204, train_loss_epoch=1.620, train_acc=0.221]
# Epoch 22, global step 230: 'val_loss' was not in top 1
# Epoch 22, global step 230: 'step' reached 230.00000 (best 230.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=22.last.ckpt' as top 1
# Epoch 23: 100%|██████████| 10/10 [00:00<00:00, 22.13it/s, v_num=1, train_loss_step=1.560, val_loss=1.630, val_acc=0.202, train_loss_epoch=1.610, train_acc=0.227]
# Epoch 23, global step 240: 'val_loss' was not in top 1
# Epoch 23, global step 240: 'step' reached 240.00000 (best 240.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=23.last.ckpt' as top 1
# Epoch 24: 100%|██████████| 10/10 [00:00<00:00, 17.50it/s, v_num=1, train_loss_step=1.620, val_loss=1.630, val_acc=0.210, train_loss_epoch=1.610, train_acc=0.230]
# Epoch 24, global step 250: 'val_loss' was not in top 1
# Epoch 24, global step 250: 'step' reached 250.00000 (best 250.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=24.last.ckpt' as top 1
# Epoch 25: 100%|██████████| 10/10 [00:00<00:00, 21.88it/s, v_num=1, train_loss_step=1.570, val_loss=1.630, val_acc=0.205, train_loss_epoch=1.610, train_acc=0.241]
# Epoch 25, global step 260: 'val_loss' was not in top 1
# Epoch 25, global step 260: 'step' reached 260.00000 (best 260.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=25.last.ckpt' as top 1
# Epoch 26: 100%|██████████| 10/10 [00:00<00:00, 21.21it/s, v_num=1, train_loss_step=1.580, val_loss=1.630, val_acc=0.203, train_loss_epoch=1.610, train_acc=0.233]
# Epoch 26, global step 270: 'val_loss' was not in top 1
# Epoch 26, global step 270: 'step' reached 270.00000 (best 270.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=26.last.ckpt' as top 1
# Epoch 27: 100%|██████████| 10/10 [00:00<00:00, 22.82it/s, v_num=1, train_loss_step=1.600, val_loss=1.630, val_acc=0.202, train_loss_epoch=1.600, train_acc=0.240]
# Epoch 27, global step 280: 'val_loss' was not in top 1
# Epoch 27, global step 280: 'step' reached 280.00000 (best 280.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=27.last.ckpt' as top 1
# Epoch 28: 100%|██████████| 10/10 [00:00<00:00, 21.52it/s, v_num=1, train_loss_step=1.590, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.600, train_acc=0.241]
# Epoch 28, global step 290: 'val_loss' was not in top 1
# Epoch 28, global step 290: 'step' reached 290.00000 (best 290.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=28.last.ckpt' as top 1
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 14.61it/s, v_num=1, train_loss_step=1.600, val_loss=1.630, val_acc=0.200, train_loss_epoch=1.590, train_acc=0.258]
# Epoch 29, global step 300: 'val_loss' was not in top 1
# Epoch 29, global step 300: 'step' reached 300.00000 (best 300.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=29.last.ckpt' as top 1
# Epoch 30: 100%|██████████| 10/10 [00:00<00:00, 21.42it/s, v_num=1, train_loss_step=1.550, val_loss=1.630, val_acc=0.198, train_loss_epoch=1.610, train_acc=0.236]
# Epoch 30, global step 310: 'val_loss' was not in top 1
# Epoch 30, global step 310: 'step' reached 310.00000 (best 310.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=30.last.ckpt' as top 1
# Epoch 31: 100%|██████████| 10/10 [00:00<00:00, 21.52it/s, v_num=1, train_loss_step=1.560, val_loss=1.630, val_acc=0.198, train_loss_epoch=1.590, train_acc=0.262]
# Epoch 31, global step 320: 'val_loss' was not in top 1
# Epoch 31, global step 320: 'step' reached 320.00000 (best 320.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=31.last.ckpt' as top 1
# Epoch 32: 100%|██████████| 10/10 [00:00<00:00, 25.48it/s, v_num=1, train_loss_step=1.540, val_loss=1.630, val_acc=0.188, train_loss_epoch=1.590, train_acc=0.256]
# Epoch 32, global step 330: 'val_loss' was not in top 1
# Epoch 32, global step 330: 'step' reached 330.00000 (best 330.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=32.last.ckpt' as top 1
# Epoch 33: 100%|██████████| 10/10 [00:00<00:00, 20.04it/s, v_num=1, train_loss_step=1.580, val_loss=1.630, val_acc=0.190, train_loss_epoch=1.590, train_acc=0.266]
# Epoch 33, global step 340: 'val_loss' was not in top 1
# Epoch 33, global step 340: 'step' reached 340.00000 (best 340.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=33.last.ckpt' as top 1
# Epoch 34: 100%|██████████| 10/10 [00:00<00:00, 24.02it/s, v_num=1, train_loss_step=1.600, val_loss=1.630, val_acc=0.180, train_loss_epoch=1.590, train_acc=0.261]
# Epoch 34, global step 350: 'val_loss' was not in top 1
# Epoch 34, global step 350: 'step' reached 350.00000 (best 350.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=34.last.ckpt' as top 1
# Epoch 35: 100%|██████████| 10/10 [00:00<00:00, 22.26it/s, v_num=1, train_loss_step=1.620, val_loss=1.630, val_acc=0.185, train_loss_epoch=1.580, train_acc=0.262]
# Epoch 35, global step 360: 'val_loss' was not in top 1
# Epoch 35, global step 360: 'step' reached 360.00000 (best 360.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=35.last.ckpt' as top 1
# Epoch 36: 100%|██████████| 10/10 [00:00<00:00, 24.39it/s, v_num=1, train_loss_step=1.570, val_loss=1.630, val_acc=0.192, train_loss_epoch=1.580, train_acc=0.271]
# Epoch 36, global step 370: 'val_loss' was not in top 1
# Epoch 36, global step 370: 'step' reached 370.00000 (best 370.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=36.last.ckpt' as top 1
# Epoch 37: 100%|██████████| 10/10 [00:00<00:00, 12.36it/s, v_num=1, train_loss_step=1.520, val_loss=1.630, val_acc=0.191, train_loss_epoch=1.580, train_acc=0.255]
# Epoch 37, global step 380: 'val_loss' was not in top 1
# Epoch 37, global step 380: 'step' reached 380.00000 (best 380.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=37.last.ckpt' as top 1
# Epoch 38: 100%|██████████| 10/10 [00:00<00:00, 12.23it/s, v_num=1, train_loss_step=1.580, val_loss=1.630, val_acc=0.196, train_loss_epoch=1.570, train_acc=0.271]
# Epoch 38, global step 390: 'val_loss' was not in top 1
# Epoch 38, global step 390: 'step' reached 390.00000 (best 390.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=38.last.ckpt' as top 1
# Epoch 39: 100%|██████████| 10/10 [00:00<00:00, 24.66it/s, v_num=1, train_loss_step=1.580, val_loss=1.630, val_acc=0.195, train_loss_epoch=1.570, train_acc=0.265]
# Epoch 39, global step 400: 'val_loss' was not in top 1
# Epoch 39, global step 400: 'step' reached 400.00000 (best 400.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=39.last.ckpt' as top 1
# Epoch 40: 100%|██████████| 10/10 [00:00<00:00, 28.17it/s, v_num=1, train_loss_step=1.600, val_loss=1.630, val_acc=0.185, train_loss_epoch=1.570, train_acc=0.278]
# Epoch 40, global step 410: 'val_loss' was not in top 1
# Epoch 40, global step 410: 'step' reached 410.00000 (best 410.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=40.last.ckpt' as top 1
# Epoch 41: 100%|██████████| 10/10 [00:00<00:00, 25.81it/s, v_num=1, train_loss_step=1.560, val_loss=1.630, val_acc=0.186, train_loss_epoch=1.570, train_acc=0.278]
# Epoch 41, global step 420: 'val_loss' was not in top 1
# Epoch 41, global step 420: 'step' reached 420.00000 (best 420.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=41.last.ckpt' as top 1
# Epoch 42: 100%|██████████| 10/10 [00:00<00:00, 27.15it/s, v_num=1, train_loss_step=1.570, val_loss=1.640, val_acc=0.176, train_loss_epoch=1.570, train_acc=0.277]
# Epoch 42, global step 430: 'val_loss' was not in top 1
# Epoch 42, global step 430: 'step' reached 430.00000 (best 430.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=42.last.ckpt' as top 1
# Epoch 43: 100%|██████████| 10/10 [00:00<00:00, 19.98it/s, v_num=1, train_loss_step=1.520, val_loss=1.640, val_acc=0.183, train_loss_epoch=1.560, train_acc=0.305]
# Epoch 43, global step 440: 'val_loss' was not in top 1
# Epoch 43, global step 440: 'step' reached 440.00000 (best 440.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=43.last.ckpt' as top 1
# Epoch 44: 100%|██████████| 10/10 [00:00<00:00, 26.46it/s, v_num=1, train_loss_step=1.570, val_loss=1.640, val_acc=0.185, train_loss_epoch=1.560, train_acc=0.292]
# Epoch 44, global step 450: 'val_loss' was not in top 1
# Epoch 44, global step 450: 'step' reached 450.00000 (best 450.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=44.last.ckpt' as top 1
# Epoch 45: 100%|██████████| 10/10 [00:00<00:00, 19.41it/s, v_num=1, train_loss_step=1.600, val_loss=1.640, val_acc=0.189, train_loss_epoch=1.550, train_acc=0.299]
# Epoch 45, global step 460: 'val_loss' was not in top 1
# Epoch 45, global step 460: 'step' reached 460.00000 (best 460.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=45.last.ckpt' as top 1
# Epoch 46: 100%|██████████| 10/10 [00:00<00:00, 28.21it/s, v_num=1, train_loss_step=1.550, val_loss=1.640, val_acc=0.193, train_loss_epoch=1.550, train_acc=0.294]
# Epoch 46, global step 470: 'val_loss' was not in top 1
# Epoch 46, global step 470: 'step' reached 470.00000 (best 470.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=46.last.ckpt' as top 1
# Epoch 47: 100%|██████████| 10/10 [00:00<00:00, 22.90it/s, v_num=1, train_loss_step=1.520, val_loss=1.640, val_acc=0.190, train_loss_epoch=1.560, train_acc=0.297]
# Epoch 47, global step 480: 'val_loss' was not in top 1
# Epoch 47, global step 480: 'step' reached 480.00000 (best 480.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=47.last.ckpt' as top 1
# Epoch 48: 100%|██████████| 10/10 [00:00<00:00, 21.80it/s, v_num=1, train_loss_step=1.580, val_loss=1.640, val_acc=0.186, train_loss_epoch=1.550, train_acc=0.310]
# Epoch 48, global step 490: 'val_loss' was not in top 1
# Epoch 48, global step 490: 'step' reached 490.00000 (best 490.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=48.last.ckpt' as top 1
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 20.31it/s, v_num=1, train_loss_step=1.560, val_loss=1.640, val_acc=0.189, train_loss_epoch=1.550, train_acc=0.304]
# Epoch 49, global step 500: 'val_loss' was not in top 1
# Epoch 49, global step 500: 'step' reached 500.00000 (best 500.00000), saving model to 'lightning_logs\\StressLevelTraining\\version_1\\checkpoints\\epoch=49.last.ckpt' as top 1
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 19.31it/s, v_num=1, train_loss_step=1.560, val_loss=1.640, val_acc=0.189, train_loss_epoch=1.540, train_acc=0.312]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# ✓ Model exported to ONNX: models\stress_level_model.onnx
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 14.48it/s, v_num=1, train_loss_step=1.560, val_loss=1.640, val_acc=0.189, train_loss_epoch=1.540, train_acc=0.312]
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:160: `.test(ckpt_path="best")` is called with Trainer configured with multiple `ModelCheckpoint` callbacks. It will use the best checkpoint path from first checkpoint callback.
# Restoring states from the checkpoint path at lightning_logs\StressLevelTraining\version_1\checkpoints\epoch=0-val_loss=1.61.best.ckpt
# Loaded model weights from the checkpoint at lightning_logs\StressLevelTraining\version_1\checkpoints\epoch=0-val_loss=1.61.best.ckpt
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 37.66it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.20191580057144165
#          test_f1            0.0857270285487175
#         test_loss           1.6138904094696045
#      test_precision         0.1093897819519043
#        test_recall          0.20191580057144165
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
