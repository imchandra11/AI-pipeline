# %%
print("hello world!")
# Out:
# hello world!

# %%
from ImageClassification.modelmodule import ModelModuleIMG
from ImageClassification.datamodule import DataModuleIMG

# %run ImageClassification/mainfittest.py --config FoodClassification/configs/food.yaml --config FoodClassification/configs/food.local.yaml
# Out:
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\fabric\utilities\seed.py:44: No seed found, seed set to 0
# Seed set to 0
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\cli.py:734: `ModelModuleIMG.configure_optimizers` will be overridden by `IMGLightningCLI.configure_optimizers`.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#    | Name            | Type                     | Params | Mode  | FLOPs
# ------------------------------------------------------------------------------
# 0  | model           | ImageClassificationModel | 53.1 M | train | 0
# 1  | criterion       | CrossEntropyLoss         | 0      | train | 0
# 2  | train_accuracy  | MulticlassAccuracy       | 0      | train | 0
# 3  | val_accuracy    | MulticlassAccuracy       | 0      | train | 0
# 4  | test_accuracy   | MulticlassAccuracy       | 0      | train | 0
# 5  | train_f1        | MulticlassF1Score        | 0      | train | 0
# 6  | val_f1          | MulticlassF1Score        | 0      | train | 0
# 7  | test_f1         | MulticlassF1Score        | 0      | train | 0
# 8  | train_precision | MulticlassPrecision      | 0      | train | 0
# 9  | val_precision   | MulticlassPrecision      | 0      | train | 0
# 10 | test_precision  | MulticlassPrecision      | 0      | train | 0
# 11 | train_recall    | MulticlassRecall         | 0      | train | 0
# 12 | val_recall      | MulticlassRecall         | 0      | train | 0
# 13 | test_recall     | MulticlassRecall         | 0      | train | 0
# ------------------------------------------------------------------------------
# 53.1 M    Trainable params
# 0         Non-trainable params
# 53.1 M    Total params
# 212.269   Total estimated model params size (MB)
# 42        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 13/13 [00:35<00:00,  0.36it/s, v_num=0, train_loss_step=1.570, val_loss=1.080, val_acc=0.533]
# Epoch 0, global step 13: 'val_acc' reached 0.53333 (best 0.53333), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=0-val_acc=0.53.best.ckpt' as top 1
# Epoch 0, global step 13: 'step' reached 13.00000 (best 13.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=0.last.ckpt' as top 1
# Epoch 1: 100%|██████████| 13/13 [00:33<00:00,  0.38it/s, v_num=0, train_loss_step=1.390, val_loss=0.986, val_acc=0.667, train_loss_epoch=1.230, train_acc=0.270]
# Epoch 1, global step 26: 'val_acc' reached 0.66667 (best 0.66667), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=1-val_acc=0.67.best.ckpt' as top 1
# Epoch 1, global step 26: 'step' reached 26.00000 (best 26.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=1.last.ckpt' as top 1
# Epoch 2: 100%|██████████| 13/13 [00:33<00:00,  0.39it/s, v_num=0, train_loss_step=1.480, val_loss=0.880, val_acc=0.733, train_loss_epoch=1.110, train_acc=0.406]
# Epoch 2, global step 39: 'val_acc' reached 0.73333 (best 0.73333), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=2-val_acc=0.73.best.ckpt' as top 1
# Epoch 2, global step 39: 'step' reached 39.00000 (best 39.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=2.last.ckpt' as top 1
# Epoch 3: 100%|██████████| 13/13 [00:31<00:00,  0.42it/s, v_num=0, train_loss_step=0.902, val_loss=0.875, val_acc=0.600, train_loss_epoch=1.070, train_acc=0.443]
# Epoch 3, global step 52: 'val_acc' was not in top 1
# Epoch 3, global step 52: 'step' reached 52.00000 (best 52.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=3.last.ckpt' as top 1
# Epoch 4: 100%|██████████| 13/13 [00:30<00:00,  0.43it/s, v_num=0, train_loss_step=0.930, val_loss=0.877, val_acc=0.667, train_loss_epoch=1.080, train_acc=0.462]
# Epoch 4, global step 65: 'val_acc' was not in top 1
# Epoch 4, global step 65: 'step' reached 65.00000 (best 65.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=4.last.ckpt' as top 1
# Epoch 5: 100%|██████████| 13/13 [00:28<00:00,  0.45it/s, v_num=0, train_loss_step=0.796, val_loss=0.855, val_acc=0.500, train_loss_epoch=0.948, train_acc=0.520]
# Epoch 5, global step 78: 'val_acc' was not in top 1
# Epoch 5, global step 78: 'step' reached 78.00000 (best 78.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=5.last.ckpt' as top 1
# Epoch 6: 100%|██████████| 13/13 [00:28<00:00,  0.45it/s, v_num=0, train_loss_step=1.310, val_loss=0.818, val_acc=0.650, train_loss_epoch=0.908, train_acc=0.574]
# Epoch 6, global step 91: 'val_acc' was not in top 1
# Epoch 6, global step 91: 'step' reached 91.00000 (best 91.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=6.last.ckpt' as top 1
# Epoch 7: 100%|██████████| 13/13 [00:29<00:00,  0.43it/s, v_num=0, train_loss_step=0.660, val_loss=0.772, val_acc=0.633, train_loss_epoch=0.925, train_acc=0.553]
# Epoch 7, global step 104: 'val_acc' was not in top 1
# Epoch 7, global step 104: 'step' reached 104.00000 (best 104.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=7.last.ckpt' as top 1
# Epoch 8: 100%|██████████| 13/13 [00:28<00:00,  0.46it/s, v_num=0, train_loss_step=0.957, val_loss=0.723, val_acc=0.800, train_loss_epoch=0.893, train_acc=0.595]
# Epoch 8, global step 117: 'val_acc' reached 0.80000 (best 0.80000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=8-val_acc=0.80.best.ckpt' as top 1
# Epoch 8, global step 117: 'step' reached 117.00000 (best 117.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=8.last.ckpt' as top 1
# Epoch 9: 100%|██████████| 13/13 [00:28<00:00,  0.46it/s, v_num=0, train_loss_step=0.666, val_loss=0.711, val_acc=0.733, train_loss_epoch=0.781, train_acc=0.653]
# Epoch 9, global step 130: 'val_acc' was not in top 1
# Epoch 9, global step 130: 'step' reached 130.00000 (best 130.00000), saving model to 'FoodClassification/lightning_logs\\YourProjectTraining\\version_0\\checkpoints\\epoch=9.last.ckpt' as top 1
# Epoch 9: 100%|██████████| 13/13 [00:31<00:00,  0.42it/s, v_num=0, train_loss_step=0.666, val_loss=0.711, val_acc=0.733, train_loss_epoch=0.869, train_acc=0.519]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# ✓ Model exported to ONNX: FoodClassification\models\your_model_name.onnx
# Epoch 9: 100%|██████████| 13/13 [00:33<00:00,  0.39it/s, v_num=0, train_loss_step=0.666, val_loss=0.711, val_acc=0.733, train_loss_epoch=0.869, train_acc=0.519]
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:160: `.test(ckpt_path="best")` is called with Trainer configured with multiple `ModelCheckpoint` callbacks. It will use the best checkpoint path from first checkpoint callback.
# Restoring states from the checkpoint path at FoodClassification/lightning_logs\YourProjectTraining\version_0\checkpoints\epoch=8-val_acc=0.80.best.ckpt
# Loaded model weights from the checkpoint at FoodClassification/lightning_logs\YourProjectTraining\version_0\checkpoints\epoch=8-val_acc=0.80.best.ckpt
# c:\Users\91838\Desktop\AI-pipeline\.venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|██████████| 4/4 [00:02<00:00,  1.92it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc             0.800000011920929
#          test_f1            0.7802197933197021
#         test_loss           0.7234757542610168
#      test_precision                0.875
#        test_recall           0.800000011920929
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
import joblib
import onnxruntime as ort
import numpy as np
from PIL import Image
from torchvision import transforms
from pathlib import Path

# Setup paths
MODELS_DIR = Path("FoodClassification/models")
IMAGE_SIZE = (224, 224)

# Load label encoder
label_encoder = joblib.load(MODELS_DIR / "label_encoder.joblib")

# Load ONNX model
session = ort.InferenceSession(str(MODELS_DIR / "food_classification_model.onnx"))

# Prepare transforms (same as validation)
transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load and preprocess image
image_path = "C:/Users/91838/Desktop/AI-pipeline/FoodClassification/data/images/chai/253.jpg"
image = Image.open(image_path).convert('RGB')
image_tensor = transform(image).unsqueeze(0).numpy().astype(np.float32)

# Predict
input_name = session.get_inputs()[0].name
output = session.run(None, {input_name: image_tensor})
logits = output[0][0]

# Get predicted class
predicted_class_idx = int(np.argmax(logits))
predicted_class = label_encoder.inverse_transform([predicted_class_idx])[0]
confidence = float(np.exp(logits[predicted_class_idx]) / np.sum(np.exp(logits)))

print(f"Predicted class: {predicted_class}")
print(f"Confidence: {confidence * 100:.2f}%")
# Out:
# Predicted class: chai
# Confidence: 79.65%
