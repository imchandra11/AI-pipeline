# %%
from Regression.modelmodule import ModelModuleRGS
from Regression.datamodule import DataModuleRGS

# %run Regression/mainfittest.py --config DowryCalculator/configs/dowry.yaml
# Out:
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\fabric\utilities\seed.py:44: No seed found, seed set to 0
# Seed set to 0
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\cli.py:734: `ModelModuleRGS.configure_optimizers` will be overridden by `RGSLightningCLI.configure_optimizers`.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:479: You passed `Trainer(accelerator='cpu', precision='16-mixed')` but AMP with fp16 is not supported on CPU. Using `precision='bf16-mixed'` instead.
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\utilities\model_summary\model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#   | Name      | Type            | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | model     | RegressionModel | 13.8 K | train | 0
# 1 | criterion | MSELoss         | 0      | train | 0
# --------------------------------------------------------------
# 13.8 K    Trainable params
# 0         Non-trainable params
# 13.8 K    Total params
# 0.055     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 16: 'val_loss' reached 362.27637 (best 362.27637), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=0-val_loss=362.28.best.ckpt' as top 1
# Epoch 0, global step 16: 'step' reached 16.00000 (best 16.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=0.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1, global step 32: 'val_loss' reached 359.06238 (best 359.06238), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=1-val_loss=359.06.best.ckpt' as top 1
# Epoch 1, global step 32: 'step' reached 32.00000 (best 32.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=1.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 48: 'val_loss' reached 356.32074 (best 356.32074), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=2-val_loss=356.32.best.ckpt' as top 1
# Epoch 2, global step 48: 'step' reached 48.00000 (best 48.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=2.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 64: 'val_loss' reached 354.71774 (best 354.71774), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=3-val_loss=354.72.best.ckpt' as top 1
# Epoch 3, global step 64: 'step' reached 64.00000 (best 64.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=3.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 80: 'val_loss' reached 353.54016 (best 353.54016), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=4-val_loss=353.54.best.ckpt' as top 1
# Epoch 4, global step 80: 'step' reached 80.00000 (best 80.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=4.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5, global step 96: 'val_loss' reached 352.59131 (best 352.59131), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=5-val_loss=352.59.best.ckpt' as top 1
# Epoch 5, global step 96: 'step' reached 96.00000 (best 96.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=5.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6, global step 112: 'val_loss' reached 351.84470 (best 351.84470), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=6-val_loss=351.84.best.ckpt' as top 1
# Epoch 6, global step 112: 'step' reached 112.00000 (best 112.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=6.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7, global step 128: 'val_loss' reached 350.77481 (best 350.77481), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=7-val_loss=350.77.best.ckpt' as top 1
# Epoch 7, global step 128: 'step' reached 128.00000 (best 128.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=7.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8, global step 144: 'val_loss' reached 349.65833 (best 349.65833), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=8-val_loss=349.66.best.ckpt' as top 1
# Epoch 8, global step 144: 'step' reached 144.00000 (best 144.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=8.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9, global step 160: 'val_loss' reached 348.15936 (best 348.15936), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=9-val_loss=348.16.best.ckpt' as top 1
# Epoch 9, global step 160: 'step' reached 160.00000 (best 160.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_0\\checkpoints\\epoch=9.last.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=10` reached.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:160: `.test(ckpt_path="best")` is called with Trainer configured with multiple `ModelCheckpoint` callbacks. It will use the best checkpoint path from first checkpoint callback.
# Restoring states from the checkpoint path at DowryCalculator/lightning_logs\DowryTraining\version_0\checkpoints\epoch=9-val_loss=348.16.best.ckpt
# Loaded model weights from the checkpoint at DowryCalculator/lightning_logs\DowryTraining\version_0\checkpoints\epoch=9-val_loss=348.16.best.ckpt
# ✓ Model exported to ONNX: DowryCalculator\models\dowry_model.onnx
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           348.15936279296875
#         test_mae             17.78978157043457
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
