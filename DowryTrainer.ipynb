# %%
from Regression.modelmodule import ModelModuleRGS
from Regression.datamodule import DataModuleRGS

# %run Regression/mainfittest.py --config DowryCalculator/configs/dowry.yaml
# Out:
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\fabric\utilities\seed.py:44: No seed found, seed set to 0
# Seed set to 0
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\cli.py:734: `ModelModuleRGS.configure_optimizers` will be overridden by `RGSLightningCLI.configure_optimizers`.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:479: You passed `Trainer(accelerator='cpu', precision='16-mixed')` but AMP with fp16 is not supported on CPU. Using `precision='bf16-mixed'` instead.
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\utilities\model_summary\model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#   | Name      | Type            | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | model     | RegressionModel | 13.8 K | train | 0
# 1 | criterion | MSELoss         | 0      | train | 0
# --------------------------------------------------------------
# 13.8 K    Trainable params
# 0         Non-trainable params
# 13.8 K    Total params
# 0.055     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 16: 'val_loss' reached 362.27637 (best 362.27637), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=0-val_loss=362.28.best.ckpt' as top 1
# Epoch 0, global step 16: 'step' reached 16.00000 (best 16.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=0.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1, global step 32: 'val_loss' reached 359.06238 (best 359.06238), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=1-val_loss=359.06.best.ckpt' as top 1
# Epoch 1, global step 32: 'step' reached 32.00000 (best 32.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=1.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 48: 'val_loss' reached 356.32074 (best 356.32074), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=2-val_loss=356.32.best.ckpt' as top 1
# Epoch 2, global step 48: 'step' reached 48.00000 (best 48.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=2.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 64: 'val_loss' reached 354.71774 (best 354.71774), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=3-val_loss=354.72.best.ckpt' as top 1
# Epoch 3, global step 64: 'step' reached 64.00000 (best 64.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=3.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 80: 'val_loss' reached 353.54016 (best 353.54016), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=4-val_loss=353.54.best.ckpt' as top 1
# Epoch 4, global step 80: 'step' reached 80.00000 (best 80.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=4.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5, global step 96: 'val_loss' reached 352.59131 (best 352.59131), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=5-val_loss=352.59.best.ckpt' as top 1
# Epoch 5, global step 96: 'step' reached 96.00000 (best 96.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=5.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6, global step 112: 'val_loss' reached 351.84470 (best 351.84470), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=6-val_loss=351.84.best.ckpt' as top 1
# Epoch 6, global step 112: 'step' reached 112.00000 (best 112.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=6.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7, global step 128: 'val_loss' reached 350.77481 (best 350.77481), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=7-val_loss=350.77.best.ckpt' as top 1
# Epoch 7, global step 128: 'step' reached 128.00000 (best 128.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=7.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8, global step 144: 'val_loss' reached 349.65833 (best 349.65833), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=8-val_loss=349.66.best.ckpt' as top 1
# Epoch 8, global step 144: 'step' reached 144.00000 (best 144.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=8.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9, global step 160: 'val_loss' reached 348.15936 (best 348.15936), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=9-val_loss=348.16.best.ckpt' as top 1
# Epoch 9, global step 160: 'step' reached 160.00000 (best 160.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=9.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10, global step 176: 'val_loss' reached 346.81702 (best 346.81702), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=10-val_loss=346.82.best.ckpt' as top 1
# Epoch 10, global step 176: 'step' reached 176.00000 (best 176.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=10.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 11, global step 192: 'val_loss' reached 345.54639 (best 345.54639), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=11-val_loss=345.55.best.ckpt' as top 1
# Epoch 11, global step 192: 'step' reached 192.00000 (best 192.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=11.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 12, global step 208: 'val_loss' reached 344.17795 (best 344.17795), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=12-val_loss=344.18.best.ckpt' as top 1
# Epoch 12, global step 208: 'step' reached 208.00000 (best 208.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=12.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 13, global step 224: 'val_loss' reached 342.48080 (best 342.48080), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=13-val_loss=342.48.best.ckpt' as top 1
# Epoch 13, global step 224: 'step' reached 224.00000 (best 224.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=13.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 14, global step 240: 'val_loss' reached 339.73770 (best 339.73770), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=14-val_loss=339.74.best.ckpt' as top 1
# Epoch 14, global step 240: 'step' reached 240.00000 (best 240.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=14.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 15, global step 256: 'val_loss' reached 338.71506 (best 338.71506), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=15-val_loss=338.72.best.ckpt' as top 1
# Epoch 15, global step 256: 'step' reached 256.00000 (best 256.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=15.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 16, global step 272: 'val_loss' reached 337.54532 (best 337.54532), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=16-val_loss=337.55.best.ckpt' as top 1
# Epoch 16, global step 272: 'step' reached 272.00000 (best 272.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=16.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 17, global step 288: 'val_loss' reached 335.67035 (best 335.67035), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=17-val_loss=335.67.best.ckpt' as top 1
# Epoch 17, global step 288: 'step' reached 288.00000 (best 288.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=17.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 18, global step 304: 'val_loss' reached 333.09265 (best 333.09265), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=18-val_loss=333.09.best.ckpt' as top 1
# Epoch 18, global step 304: 'step' reached 304.00000 (best 304.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=18.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 19, global step 320: 'val_loss' reached 331.23767 (best 331.23767), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=19-val_loss=331.24.best.ckpt' as top 1
# Epoch 19, global step 320: 'step' reached 320.00000 (best 320.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=19.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 20, global step 336: 'val_loss' reached 329.73950 (best 329.73950), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=20-val_loss=329.74.best.ckpt' as top 1
# Epoch 20, global step 336: 'step' reached 336.00000 (best 336.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=20.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 21, global step 352: 'val_loss' reached 327.69958 (best 327.69958), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=21-val_loss=327.70.best.ckpt' as top 1
# Epoch 21, global step 352: 'step' reached 352.00000 (best 352.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=21.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 22, global step 368: 'val_loss' reached 325.43564 (best 325.43564), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=22-val_loss=325.44.best.ckpt' as top 1
# Epoch 22, global step 368: 'step' reached 368.00000 (best 368.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=22.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 23, global step 384: 'val_loss' reached 322.88132 (best 322.88132), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=23-val_loss=322.88.best.ckpt' as top 1
# Epoch 23, global step 384: 'step' reached 384.00000 (best 384.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=23.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 24, global step 400: 'val_loss' reached 320.22507 (best 320.22507), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=24-val_loss=320.23.best.ckpt' as top 1
# Epoch 24, global step 400: 'step' reached 400.00000 (best 400.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=24.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 25, global step 416: 'val_loss' reached 318.01834 (best 318.01834), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=25-val_loss=318.02.best.ckpt' as top 1
# Epoch 25, global step 416: 'step' reached 416.00000 (best 416.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=25.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 26, global step 432: 'val_loss' reached 315.71875 (best 315.71875), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=26-val_loss=315.72.best.ckpt' as top 1
# Epoch 26, global step 432: 'step' reached 432.00000 (best 432.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=26.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 27, global step 448: 'val_loss' reached 313.05029 (best 313.05029), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=27-val_loss=313.05.best.ckpt' as top 1
# Epoch 27, global step 448: 'step' reached 448.00000 (best 448.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=27.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 28, global step 464: 'val_loss' reached 310.68109 (best 310.68109), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=28-val_loss=310.68.best.ckpt' as top 1
# Epoch 28, global step 464: 'step' reached 464.00000 (best 464.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=28.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 29, global step 480: 'val_loss' reached 307.41025 (best 307.41025), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=29-val_loss=307.41.best.ckpt' as top 1
# Epoch 29, global step 480: 'step' reached 480.00000 (best 480.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=29.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 30, global step 496: 'val_loss' reached 303.85681 (best 303.85681), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=30-val_loss=303.86.best.ckpt' as top 1
# Epoch 30, global step 496: 'step' reached 496.00000 (best 496.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=30.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 31, global step 512: 'val_loss' reached 300.28397 (best 300.28397), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=31-val_loss=300.28.best.ckpt' as top 1
# Epoch 31, global step 512: 'step' reached 512.00000 (best 512.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=31.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 32, global step 528: 'val_loss' reached 297.37537 (best 297.37537), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=32-val_loss=297.38.best.ckpt' as top 1
# Epoch 32, global step 528: 'step' reached 528.00000 (best 528.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=32.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 33, global step 544: 'val_loss' reached 293.46951 (best 293.46951), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=33-val_loss=293.47.best.ckpt' as top 1
# Epoch 33, global step 544: 'step' reached 544.00000 (best 544.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=33.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 34, global step 560: 'val_loss' reached 289.10007 (best 289.10007), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=34-val_loss=289.10.best.ckpt' as top 1
# Epoch 34, global step 560: 'step' reached 560.00000 (best 560.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=34.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 35, global step 576: 'val_loss' reached 286.44775 (best 286.44775), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=35-val_loss=286.45.best.ckpt' as top 1
# Epoch 35, global step 576: 'step' reached 576.00000 (best 576.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=35.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 36, global step 592: 'val_loss' reached 280.04813 (best 280.04813), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=36-val_loss=280.05.best.ckpt' as top 1
# Epoch 36, global step 592: 'step' reached 592.00000 (best 592.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=36.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 37, global step 608: 'val_loss' reached 276.88419 (best 276.88419), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=37-val_loss=276.88.best.ckpt' as top 1
# Epoch 37, global step 608: 'step' reached 608.00000 (best 608.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=37.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 38, global step 624: 'val_loss' reached 271.24097 (best 271.24097), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=38-val_loss=271.24.best.ckpt' as top 1
# Epoch 38, global step 624: 'step' reached 624.00000 (best 624.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=38.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 39, global step 640: 'val_loss' reached 267.44452 (best 267.44452), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=39-val_loss=267.44.best.ckpt' as top 1
# Epoch 39, global step 640: 'step' reached 640.00000 (best 640.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=39.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 40, global step 656: 'val_loss' reached 261.87823 (best 261.87823), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=40-val_loss=261.88.best.ckpt' as top 1
# Epoch 40, global step 656: 'step' reached 656.00000 (best 656.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=40.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 41, global step 672: 'val_loss' reached 255.83540 (best 255.83540), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=41-val_loss=255.84.best.ckpt' as top 1
# Epoch 41, global step 672: 'step' reached 672.00000 (best 672.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=41.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 42, global step 688: 'val_loss' reached 247.71449 (best 247.71449), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=42-val_loss=247.71.best.ckpt' as top 1
# Epoch 42, global step 688: 'step' reached 688.00000 (best 688.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=42.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 43, global step 704: 'val_loss' reached 242.11209 (best 242.11209), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=43-val_loss=242.11.best.ckpt' as top 1
# Epoch 43, global step 704: 'step' reached 704.00000 (best 704.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=43.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 44, global step 720: 'val_loss' reached 233.27899 (best 233.27899), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=44-val_loss=233.28.best.ckpt' as top 1
# Epoch 44, global step 720: 'step' reached 720.00000 (best 720.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=44.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 45, global step 736: 'val_loss' reached 227.40524 (best 227.40524), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=45-val_loss=227.41.best.ckpt' as top 1
# Epoch 45, global step 736: 'step' reached 736.00000 (best 736.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=45.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 46, global step 752: 'val_loss' reached 220.11128 (best 220.11128), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=46-val_loss=220.11.best.ckpt' as top 1
# Epoch 46, global step 752: 'step' reached 752.00000 (best 752.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=46.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 47, global step 768: 'val_loss' reached 211.67068 (best 211.67068), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=47-val_loss=211.67.best.ckpt' as top 1
# Epoch 47, global step 768: 'step' reached 768.00000 (best 768.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=47.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 48, global step 784: 'val_loss' reached 204.10390 (best 204.10390), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=48-val_loss=204.10.best.ckpt' as top 1
# Epoch 48, global step 784: 'step' reached 784.00000 (best 784.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=48.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 49, global step 800: 'val_loss' reached 195.60175 (best 195.60175), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=49-val_loss=195.60.best.ckpt' as top 1
# Epoch 49, global step 800: 'step' reached 800.00000 (best 800.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=49.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 50, global step 816: 'val_loss' reached 186.85667 (best 186.85667), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=50-val_loss=186.86.best.ckpt' as top 1
# Epoch 50, global step 816: 'step' reached 816.00000 (best 816.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=50.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 51, global step 832: 'val_loss' reached 180.70715 (best 180.70715), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=51-val_loss=180.71.best.ckpt' as top 1
# Epoch 51, global step 832: 'step' reached 832.00000 (best 832.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=51.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 52, global step 848: 'val_loss' reached 170.26984 (best 170.26984), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=52-val_loss=170.27.best.ckpt' as top 1
# Epoch 52, global step 848: 'step' reached 848.00000 (best 848.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=52.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 53, global step 864: 'val_loss' reached 161.00682 (best 161.00682), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=53-val_loss=161.01.best.ckpt' as top 1
# Epoch 53, global step 864: 'step' reached 864.00000 (best 864.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=53.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 54, global step 880: 'val_loss' reached 153.35364 (best 153.35364), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=54-val_loss=153.35.best.ckpt' as top 1
# Epoch 54, global step 880: 'step' reached 880.00000 (best 880.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=54.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 55, global step 896: 'val_loss' reached 141.50525 (best 141.50525), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=55-val_loss=141.51.best.ckpt' as top 1
# Epoch 55, global step 896: 'step' reached 896.00000 (best 896.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=55.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 56, global step 912: 'val_loss' reached 131.67180 (best 131.67180), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=56-val_loss=131.67.best.ckpt' as top 1
# Epoch 56, global step 912: 'step' reached 912.00000 (best 912.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=56.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 57, global step 928: 'val_loss' reached 124.83088 (best 124.83088), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=57-val_loss=124.83.best.ckpt' as top 1
# Epoch 57, global step 928: 'step' reached 928.00000 (best 928.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=57.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 58, global step 944: 'val_loss' reached 113.41000 (best 113.41000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=58-val_loss=113.41.best.ckpt' as top 1
# Epoch 58, global step 944: 'step' reached 944.00000 (best 944.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=58.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 59, global step 960: 'val_loss' reached 105.01823 (best 105.01823), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=59-val_loss=105.02.best.ckpt' as top 1
# Epoch 59, global step 960: 'step' reached 960.00000 (best 960.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=59.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 60, global step 976: 'val_loss' reached 96.06281 (best 96.06281), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=60-val_loss=96.06.best.ckpt' as top 1
# Epoch 60, global step 976: 'step' reached 976.00000 (best 976.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=60.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 61, global step 992: 'val_loss' reached 90.44847 (best 90.44847), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=61-val_loss=90.45.best.ckpt' as top 1
# Epoch 61, global step 992: 'step' reached 992.00000 (best 992.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=61.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 62, global step 1008: 'val_loss' reached 78.34045 (best 78.34045), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=62-val_loss=78.34.best.ckpt' as top 1
# Epoch 62, global step 1008: 'step' reached 1008.00000 (best 1008.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=62.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 63, global step 1024: 'val_loss' reached 70.53523 (best 70.53523), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=63-val_loss=70.54.best.ckpt' as top 1
# Epoch 63, global step 1024: 'step' reached 1024.00000 (best 1024.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=63.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 64, global step 1040: 'val_loss' reached 63.02876 (best 63.02876), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=64-val_loss=63.03.best.ckpt' as top 1
# Epoch 64, global step 1040: 'step' reached 1040.00000 (best 1040.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=64.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 65, global step 1056: 'val_loss' reached 57.95226 (best 57.95226), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=65-val_loss=57.95.best.ckpt' as top 1
# Epoch 65, global step 1056: 'step' reached 1056.00000 (best 1056.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=65.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 66, global step 1072: 'val_loss' reached 50.30477 (best 50.30477), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=66-val_loss=50.30.best.ckpt' as top 1
# Epoch 66, global step 1072: 'step' reached 1072.00000 (best 1072.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=66.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 67, global step 1088: 'val_loss' reached 42.93979 (best 42.93979), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=67-val_loss=42.94.best.ckpt' as top 1
# Epoch 67, global step 1088: 'step' reached 1088.00000 (best 1088.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=67.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 68, global step 1104: 'val_loss' reached 37.31392 (best 37.31392), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=68-val_loss=37.31.best.ckpt' as top 1
# Epoch 68, global step 1104: 'step' reached 1104.00000 (best 1104.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=68.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 69, global step 1120: 'val_loss' reached 30.94479 (best 30.94479), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=69-val_loss=30.94.best.ckpt' as top 1
# Epoch 69, global step 1120: 'step' reached 1120.00000 (best 1120.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=69.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 70, global step 1136: 'val_loss' reached 25.87247 (best 25.87247), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=70-val_loss=25.87.best.ckpt' as top 1
# Epoch 70, global step 1136: 'step' reached 1136.00000 (best 1136.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=70.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 71, global step 1152: 'val_loss' reached 22.02779 (best 22.02779), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=71-val_loss=22.03.best.ckpt' as top 1
# Epoch 71, global step 1152: 'step' reached 1152.00000 (best 1152.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=71.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 72, global step 1168: 'val_loss' reached 19.56051 (best 19.56051), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=72-val_loss=19.56.best.ckpt' as top 1
# Epoch 72, global step 1168: 'step' reached 1168.00000 (best 1168.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=72.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 73, global step 1184: 'val_loss' reached 15.35274 (best 15.35274), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=73-val_loss=15.35.best.ckpt' as top 1
# Epoch 73, global step 1184: 'step' reached 1184.00000 (best 1184.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=73.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 74, global step 1200: 'val_loss' reached 11.98617 (best 11.98617), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=74-val_loss=11.99.best.ckpt' as top 1
# Epoch 74, global step 1200: 'step' reached 1200.00000 (best 1200.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=74.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 75, global step 1216: 'val_loss' reached 9.65629 (best 9.65629), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=75-val_loss=9.66.best.ckpt' as top 1
# Epoch 75, global step 1216: 'step' reached 1216.00000 (best 1216.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=75.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 76, global step 1232: 'val_loss' reached 8.31998 (best 8.31998), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=76-val_loss=8.32.best.ckpt' as top 1
# Epoch 76, global step 1232: 'step' reached 1232.00000 (best 1232.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=76.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 77, global step 1248: 'val_loss' reached 6.41775 (best 6.41775), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=77-val_loss=6.42.best.ckpt' as top 1
# Epoch 77, global step 1248: 'step' reached 1248.00000 (best 1248.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=77.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 78, global step 1264: 'val_loss' reached 4.76685 (best 4.76685), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=78-val_loss=4.77.best.ckpt' as top 1
# Epoch 78, global step 1264: 'step' reached 1264.00000 (best 1264.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=78.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 79, global step 1280: 'val_loss' reached 4.07215 (best 4.07215), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=79-val_loss=4.07.best.ckpt' as top 1
# Epoch 79, global step 1280: 'step' reached 1280.00000 (best 1280.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=79.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 80, global step 1296: 'val_loss' reached 3.25496 (best 3.25496), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=80-val_loss=3.25.best.ckpt' as top 1
# Epoch 80, global step 1296: 'step' reached 1296.00000 (best 1296.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=80.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 81, global step 1312: 'val_loss' reached 2.24626 (best 2.24626), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=81-val_loss=2.25.best.ckpt' as top 1
# Epoch 81, global step 1312: 'step' reached 1312.00000 (best 1312.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=81.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 82, global step 1328: 'val_loss' reached 2.14162 (best 2.14162), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=82-val_loss=2.14.best.ckpt' as top 1
# Epoch 82, global step 1328: 'step' reached 1328.00000 (best 1328.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=82.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 83, global step 1344: 'val_loss' reached 1.54186 (best 1.54186), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=83-val_loss=1.54.best.ckpt' as top 1
# Epoch 83, global step 1344: 'step' reached 1344.00000 (best 1344.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=83.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 84, global step 1360: 'val_loss' reached 1.39259 (best 1.39259), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=84-val_loss=1.39.best.ckpt' as top 1
# Epoch 84, global step 1360: 'step' reached 1360.00000 (best 1360.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=84.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 85, global step 1376: 'val_loss' reached 0.88456 (best 0.88456), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=85-val_loss=0.88.best.ckpt' as top 1
# Epoch 85, global step 1376: 'step' reached 1376.00000 (best 1376.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=85.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 86, global step 1392: 'val_loss' reached 0.78499 (best 0.78499), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=86-val_loss=0.78.best.ckpt' as top 1
# Epoch 86, global step 1392: 'step' reached 1392.00000 (best 1392.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=86.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 87, global step 1408: 'val_loss' reached 0.49479 (best 0.49479), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=87-val_loss=0.49.best.ckpt' as top 1
# Epoch 87, global step 1408: 'step' reached 1408.00000 (best 1408.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=87.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 88, global step 1424: 'val_loss' reached 0.43648 (best 0.43648), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=88-val_loss=0.44.best.ckpt' as top 1
# Epoch 88, global step 1424: 'step' reached 1424.00000 (best 1424.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=88.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 89, global step 1440: 'val_loss' reached 0.40243 (best 0.40243), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=89-val_loss=0.40.best.ckpt' as top 1
# Epoch 89, global step 1440: 'step' reached 1440.00000 (best 1440.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=89.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 90, global step 1456: 'val_loss' reached 0.23917 (best 0.23917), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=90-val_loss=0.24.best.ckpt' as top 1
# Epoch 90, global step 1456: 'step' reached 1456.00000 (best 1456.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=90.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 91, global step 1472: 'val_loss' was not in top 1
# Epoch 91, global step 1472: 'step' reached 1472.00000 (best 1472.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=91.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 92, global step 1488: 'val_loss' was not in top 1
# Epoch 92, global step 1488: 'step' reached 1488.00000 (best 1488.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=92.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 93, global step 1504: 'val_loss' was not in top 1
# Epoch 93, global step 1504: 'step' reached 1504.00000 (best 1504.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=93.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 94, global step 1520: 'val_loss' was not in top 1
# Epoch 94, global step 1520: 'step' reached 1520.00000 (best 1520.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=94.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 95, global step 1536: 'val_loss' reached 0.17907 (best 0.17907), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=95-val_loss=0.18.best.ckpt' as top 1
# Epoch 95, global step 1536: 'step' reached 1536.00000 (best 1536.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=95.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 96, global step 1552: 'val_loss' reached 0.15204 (best 0.15204), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=96-val_loss=0.15.best.ckpt' as top 1
# Epoch 96, global step 1552: 'step' reached 1552.00000 (best 1552.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=96.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 97, global step 1568: 'val_loss' was not in top 1
# Epoch 97, global step 1568: 'step' reached 1568.00000 (best 1568.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=97.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 98, global step 1584: 'val_loss' was not in top 1
# Epoch 98, global step 1584: 'step' reached 1584.00000 (best 1584.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=98.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 99, global step 1600: 'val_loss' was not in top 1
# Epoch 99, global step 1600: 'step' reached 1600.00000 (best 1600.00000), saving model to 'DowryCalculator/lightning_logs\\DowryTraining\\version_1\\checkpoints\\epoch=99.last.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:160: `.test(ckpt_path="best")` is called with Trainer configured with multiple `ModelCheckpoint` callbacks. It will use the best checkpoint path from first checkpoint callback.
# Restoring states from the checkpoint path at DowryCalculator/lightning_logs\DowryTraining\version_1\checkpoints\epoch=96-val_loss=0.15.best.ckpt
# Loaded model weights from the checkpoint at DowryCalculator/lightning_logs\DowryTraining\version_1\checkpoints\epoch=96-val_loss=0.15.best.ckpt
# ✓ Model exported to ONNX: DowryCalculator\models\dowry_model.onnx
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.1520410180091858
#         test_mae            0.3085624873638153
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
