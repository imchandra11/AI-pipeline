# %%
from Classification.modelmodule import ModelModuleCLS
from Classification.datamodule import DataModuleCLS

# %run Classification/mainfittest.py --config UpiFraudClassification//configs/upifraud.yaml

# %run Classification/mainfittest.py --config StressLevelPrediction/configs/stress.yaml --config StressLevelPrediction/configs/stress.local.yaml
# Out:
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\fabric\utilities\seed.py:44: No seed found, seed set to 0
# Seed set to 0
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\cli.py:734: `ModelModuleCLS.configure_optimizers` will be overridden by `CLSLightningCLI.configure_optimizers`.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:479: You passed `Trainer(accelerator='cpu', precision='16-mixed')` but AMP with fp16 is not supported on CPU. Using `precision='bf16-mixed'` instead.
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\utilities\model_summary\model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#    | Name            | Type                | Params | Mode  | FLOPs
# -------------------------------------------------------------------------
# 0  | model           | ClassificationModel | 12.9 K | train | 0
# 1  | criterion       | CrossEntropyLoss    | 0      | train | 0
# 2  | train_accuracy  | MulticlassAccuracy  | 0      | train | 0
# 3  | val_accuracy    | MulticlassAccuracy  | 0      | train | 0
# 4  | test_accuracy   | MulticlassAccuracy  | 0      | train | 0
# 5  | train_f1        | MulticlassF1Score   | 0      | train | 0
# 6  | val_f1          | MulticlassF1Score   | 0      | train | 0
# 7  | test_f1         | MulticlassF1Score   | 0      | train | 0
# 8  | train_precision | MulticlassPrecision | 0      | train | 0
# 9  | val_precision   | MulticlassPrecision | 0      | train | 0
# 10 | test_precision  | MulticlassPrecision | 0      | train | 0
# 11 | train_recall    | MulticlassRecall    | 0      | train | 0
# 12 | val_recall      | MulticlassRecall    | 0      | train | 0
# 13 | test_recall     | MulticlassRecall    | 0      | train | 0
# -------------------------------------------------------------------------
# 12.9 K    Trainable params
# 0         Non-trainable params
# 12.9 K    Total params
# 0.052     Total estimated model params size (MB)
# 26        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 32: 'val_loss' reached 1.13858 (best 1.13858), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=0-val_loss=1.14.best.ckpt' as top 1
# Epoch 0, global step 32: 'step' reached 32.00000 (best 32.00000), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=0.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1, global step 64: 'val_loss' reached 1.07889 (best 1.07889), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=1-val_loss=1.08.best.ckpt' as top 1
# Epoch 1, global step 64: 'step' reached 64.00000 (best 64.00000), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=1.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 96: 'val_loss' reached 1.03321 (best 1.03321), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=2-val_loss=1.03.best.ckpt' as top 1
# Epoch 2, global step 96: 'step' reached 96.00000 (best 96.00000), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=2.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3, global step 128: 'val_loss' reached 0.99598 (best 0.99598), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=3-val_loss=1.00.best.ckpt' as top 1
# Epoch 3, global step 128: 'step' reached 128.00000 (best 128.00000), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=3.last.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 160: 'val_loss' reached 0.94909 (best 0.94909), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=4-val_loss=0.95.best.ckpt' as top 1
# Epoch 4, global step 160: 'step' reached 160.00000 (best 160.00000), saving model to 'UpiFraudClassification/logs\\UpiFraudTraining\\version_2\\checkpoints\\epoch=4.last.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=5` reached.
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:160: `.test(ckpt_path="best")` is called with Trainer configured with multiple `ModelCheckpoint` callbacks. It will use the best checkpoint path from first checkpoint callback.
# Restoring states from the checkpoint path at UpiFraudClassification/logs\UpiFraudTraining\version_2\checkpoints\epoch=4-val_loss=0.95.best.ckpt
# Loaded model weights from the checkpoint at UpiFraudClassification/logs\UpiFraudTraining\version_2\checkpoints\epoch=4-val_loss=0.95.best.ckpt
# ✓ Model exported to ONNX: UpiFraudClassification\models\upi_fraud_model.onnx
# c:\Users\91838\Desktop\AI-pipeline\myvenv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.6284002065658569
#          test_f1            0.5201321840286255
#         test_loss            0.949087381362915
#      test_precision         0.5755873322486877
#        test_recall          0.6284002065658569
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
